# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
import datetime as dt

def day_since(received_date):
    return (dt.datetime.now() - received_date).days

df['days_since_posted'] = df['job_posted_date'].apply(day_since)

df[['job_posted_date', 'days_since_posted']].head()
# Out:
#       job_posted_date  days_since_posted
# 0 2023-06-16 13:44:15                987
# 1 2023-01-14 13:18:07               1140
# 2 2023-10-10 13:14:55                871
# 3 2023-07-04 13:01:41                969
# 4 2023-08-07 14:29:36                935
